# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-1.2.0-py2.py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pandas>=1.3.0 in /Users/behniakhaleghi/Projects/volatility-var-backtesting/venv/lib/python3.13/site-packages (from yfinance) (3.0.0)
# Requirement already satisfied: numpy>=1.16.5 in /Users/behniakhaleghi/Projects/volatility-var-backtesting/venv/lib/python3.13/site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: requests>=2.31 in /Users/behniakhaleghi/Projects/volatility-var-backtesting/venv/lib/python3.13/site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.12-py3-none-any.whl
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/behniakhaleghi/Projects/volatility-var-backtesting/venv/lib/python3.13/site-packages (from yfinance) (4.9.2)
# Collecting pytz>=2022.5 (from yfinance)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Using cached frozendict-2.4.7-py3-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-3.19.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/behniakhaleghi/Projects/volatility-var-backtesting/venv/lib/python3.13/site-packages (from yfinance) (4.14.3)
# Collecting curl_cffi<0.14,>=0.7 (from yfinance)
#   Using cached curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Using cached protobuf-6.33.5-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Using cached websockets-16.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: cffi>=1.12.0 in /Users/behniakhaleghi/Projects/volatility-var-backtesting/venv/lib/python3.13/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /Users/behniakhaleghi/Projects/volatility-var-backtesting/venv/lib/python3.13/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/behniakhaleghi/Projects/volatility-var-backtesting/venv/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/behniakhaleghi/Projects/volatility-var-backtesting/venv/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in /Users/behniakhaleghi/Projects/volatility-var-backtesting/venv/lib/python3.13/site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/behniakhaleghi/Projects/volatility-var-backtesting/venv/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/behniakhaleghi/Projects/volatility-var-backtesting/venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/behniakhaleghi/Projects/volatility-var-backtesting/venv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/behniakhaleghi/Projects/volatility-var-backtesting/venv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/behniakhaleghi/Projects/volatility-var-backtesting/venv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (2.6.3)
# Downloading yfinance-1.2.0-py2.py3-none-any.whl (130 kB)
# Using cached curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
# Using cached frozendict-2.4.7-py3-none-any.whl (16 kB)
# Using cached peewee-3.19.0-py3-none-any.whl (411 kB)
# Using cached protobuf-6.33.5-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached websockets-16.0-cp313-cp313-macosx_11_0_arm64.whl (175 kB)
# Installing collected packages: pytz, peewee, multitasking, websockets, protobuf, frozendict, curl_cffi, yfinance
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [yfinance]7/8 [yfinance]s]
# Successfully installed curl_cffi-0.13.0 frozendict-2.4.7 multitasking-0.0.12 peewee-3.19.0 protobuf-6.33.5 pytz-2025.2 websockets-16.0 yfinance-1.2.0

# %%
import yfinance as yf

ticker = "^GDAXI"  # DAX index
df = yf.download(ticker, start="2014-01-01", progress=False)

df.head()
# Out:
# Price             Close         High          Low         Open    Volume
# Ticker           ^GDAXI       ^GDAXI       ^GDAXI       ^GDAXI    ^GDAXI
# Date
# 2014-01-02  9400.040039  9620.929688  9394.209961  9598.250000  90956900
# 2014-01-03  9435.150391  9453.480469  9367.990234  9409.660156  58772900
# 2014-01-06  9428.000000  9468.799805  9399.809570  9419.440430  53653700
# 2014-01-07  9506.200195  9518.719727  9416.860352  9446.250000  79946800
# 2014-01-08  9497.839844  9516.259766  9467.950195  9512.790039  90140400

# %%
df.to_csv("../data/raw/dax_raw.csv")
print("Saved raw data.")
# Out:
# Saved raw data.

# %%
close = df["Close"].dropna()

ret = 100 * np.log(close / close.shift(1))
ret = ret.dropna()

ret.name = "log_return"
ret.head()
# Out:
# Ticker        ^GDAXI
# Date
# 2014-01-03  0.372817
# 2014-01-06 -0.075813
# 2014-01-07  0.826025
# 2014-01-08 -0.087985
# 2014-01-09 -0.805836

# %%
ret.to_csv("../data/processed/dax_log_returns.csv")
print("Saved processed returns.")
# Out:
# Saved processed returns.

# %%
close.plot(title="DAX Close Price")
plt.show()

# %%
ret.plot(title="DAX Daily Log Returns (x100)")
plt.show()

# %%
rolling_vol = ret.rolling(30).std()

rolling_vol.plot(title="Rolling Volatility (30-day)")
plt.show()
